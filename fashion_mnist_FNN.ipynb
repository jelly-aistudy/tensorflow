# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

fashion_mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train / 255
x_test = x_test / 255
y_train = tf.one_hot(y_train, 10)
y_test = tf.one_hot(y_test, 10)

model = Sequential([
        Flatten(input_shape=(28,28)),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(64, activation='relu'),
        Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

ckpath = 'jelly.ckpt'
checkpoint = ModelCheckpoint(filepath=ckpath,
                              save_best_only=True,
                              save_weights_only=True,
                              monitor='val_loss',
                              verbose=1)
    
earlystop = EarlyStopping(monitor='val_loss', patience=10)

BATCH_SIZE = 256
EPOCH = 50
model.fit(x_train, y_train,
          validation_data=(x_test, y_test),
          epochs=EPOCH,
          batch_size=BATCH_SIZE,
          callbacks=[checkpoint, earlystop])
    
model.load_weights(checkpoint_path)
# Out:
# Epoch 1/50
# 235/235 [==============================] - 1s 4ms/step - loss: 0.8033 - acc: 0.7256 - val_loss: 0.4524 - val_acc: 0.8366
#
# Epoch 00001: val_loss improved from inf to 0.45243, saving model to my_checkpoint.ckpt
# Epoch 2/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4010 - acc: 0.8543 - val_loss: 0.4042 - val_acc: 0.8566
#
# Epoch 00002: val_loss improved from 0.45243 to 0.40416, saving model to my_checkpoint.ckpt
# Epoch 3/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3472 - acc: 0.8744 - val_loss: 0.3706 - val_acc: 0.8676
#
# Epoch 00003: val_loss improved from 0.40416 to 0.37058, saving model to my_checkpoint.ckpt
# Epoch 4/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3167 - acc: 0.8849 - val_loss: 0.3671 - val_acc: 0.8695
#
# Epoch 00004: val_loss improved from 0.37058 to 0.36707, saving model to my_checkpoint.ckpt
# Epoch 5/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2947 - acc: 0.8931 - val_loss: 0.3582 - val_acc: 0.8727
#
# Epoch 00005: val_loss improved from 0.36707 to 0.35818, saving model to my_checkpoint.ckpt
# Epoch 6/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2704 - acc: 0.9009 - val_loss: 0.3412 - val_acc: 0.8790
#
# Epoch 00006: val_loss improved from 0.35818 to 0.34120, saving model to my_checkpoint.ckpt
# Epoch 7/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2629 - acc: 0.9031 - val_loss: 0.3731 - val_acc: 0.8717
#
# Epoch 00007: val_loss did not improve from 0.34120
# Epoch 8/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2561 - acc: 0.9057 - val_loss: 0.3316 - val_acc: 0.8820
#
# Epoch 00008: val_loss improved from 0.34120 to 0.33158, saving model to my_checkpoint.ckpt
# Epoch 9/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2520 - acc: 0.9054 - val_loss: 0.3265 - val_acc: 0.8828
#
# Epoch 00009: val_loss improved from 0.33158 to 0.32645, saving model to my_checkpoint.ckpt
# Epoch 10/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2360 - acc: 0.9127 - val_loss: 0.3315 - val_acc: 0.8821
#
# Epoch 00010: val_loss did not improve from 0.32645
# Epoch 11/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2230 - acc: 0.9168 - val_loss: 0.3165 - val_acc: 0.8873
#
# Epoch 00011: val_loss improved from 0.32645 to 0.31654, saving model to my_checkpoint.ckpt
# Epoch 12/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2077 - acc: 0.9220 - val_loss: 0.3447 - val_acc: 0.8797
#
# Epoch 00012: val_loss did not improve from 0.31654
# Epoch 13/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2048 - acc: 0.9226 - val_loss: 0.3253 - val_acc: 0.8844
#
# Epoch 00013: val_loss did not improve from 0.31654
# Epoch 14/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1989 - acc: 0.9244 - val_loss: 0.3399 - val_acc: 0.8859
#
# Epoch 00014: val_loss did not improve from 0.31654
# Epoch 15/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1899 - acc: 0.9290 - val_loss: 0.3553 - val_acc: 0.8826
#
# Epoch 00015: val_loss did not improve from 0.31654
# Epoch 16/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1901 - acc: 0.9285 - val_loss: 0.3263 - val_acc: 0.8931
#
# Epoch 00016: val_loss did not improve from 0.31654
# Epoch 17/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1843 - acc: 0.9307 - val_loss: 0.3571 - val_acc: 0.8833
#
# Epoch 00017: val_loss did not improve from 0.31654
# Epoch 18/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1728 - acc: 0.9344 - val_loss: 0.3638 - val_acc: 0.8852
#
# Epoch 00018: val_loss did not improve from 0.31654
# Epoch 19/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1672 - acc: 0.9359 - val_loss: 0.3432 - val_acc: 0.8861
#
# Epoch 00019: val_loss did not improve from 0.31654
# Epoch 20/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1620 - acc: 0.9390 - val_loss: 0.3513 - val_acc: 0.8893
#
# Epoch 00020: val_loss did not improve from 0.31654
# Epoch 21/50
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1651 - acc: 0.9361 - val_loss: 0.3594 - val_acc: 0.8884
#
# Epoch 00021: val_loss did not improve from 0.31654
